# %% [markdown]
# # Кейс "Подготовка данных для анализа"

# %% [markdown]
# ## Вариант 6

# %% [markdown]
# Даны исходные данные, которые содержат информацию о потреблении алкоголя среди студентов
#
# 1. Загрузите датасет в блокнот из файла student-mat.csv
#
# 2. Выведите информацию о датасете:
#
#     * количество строк и колонок,
#     * информацию о типах данных, нулевых и ненулевых значениях в колонках (признаках).
#
# 3. Создайте в ячейках таблицы которые отвечают на следующие вопросы:
#
#     * В новом столбце выведите информацию о том, является ли студент совершеннолетним для употребления алкоголя (True/False)
#     * Посчитайте долю по колонкам Medu и Fedu в процентах. Сумма по каждой колонке берется за 100%.
#
# 4. Решение представьте в виде ячейки с кодом на языке Python. Решение может содержать несколько строчек. Используемый пакет — `pandas`.
